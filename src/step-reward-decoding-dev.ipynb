# %%
import os

os.environ["DATA_ROOT"] = "/data/tongyx361"
os.environ["HF_HOME"] = os.path.join(os.environ["DATA_ROOT"], ".cache/huggingface")

# %%
import utils
import importlib

importlib.reload(utils)
# Out:
# [2023-10-08 03:52:31,986] [INFO] [real_accelerator.py:133:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# <module 'utils' from '/data/tongyx361/reward-by-prm800k/src/utils.py'>

# %%
tokenizer = utils.get_complete_tokenizer(
    os.path.join(
        os.environ["HF_HOME"],
        "/hub/models--hf-internal-testing--llama-tokenizer/snapshots/99eceeba6e8289bee767f0771166b5917e70e470",
    )
)
# Out:
# head_tokens = <unk><s></s>
# tokenizer.vocab_size = 32000
# len(tokenizer.vocab) = 32000
# tokenizer.special_tokens_map = {'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>'}
# num_added_tokens = 1
# head_tokens = <unk><s></s>
# tokenizer.vocab_size = 32000
# len(tokenizer.vocab) = 32001
# tokenizer.special_tokens_map = {'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'}
# LlamaTokenizerFast(name_or_path='/data/tongyx361/.cache/huggingface/hub/models--hf-internal-testing--llama-tokenizer/snapshots/99eceeba6e8289bee767f0771166b5917e70e470', vocab_size=32000, model_max_length=4096, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'}, clean_up_tokenization_spaces=False)
# {'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>'}

# %%
model = utils.get_hf_model(model_name_or_path="TIGER-Lab/MAmmoTH-7B")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data/tongyx361/reward-by-prm800k/src/step-reward-decoding-dev.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a224b45472d31307833303930227d/data/tongyx361/reward-by-prm800k/src/step-reward-decoding-dev.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> model = utils.get_hf_model(model_name_or_path="TIGER-Lab/MAmmoTH-7B")
#
# File /data/tongyx361/reward-by-prm800k/src/utils.py:1582, in get_hf_model(model_name_or_path, torch_dtype, **kwargs)
#    1580 def get_hf_model(model_name_or_path=default_7b_model_path, torch_dtype=torch.float16, **kwargs):
#    1581     """fp16, low_cpu_mem_usage"""
# -> 1582     model = transformers.AutoModelForCausalLM.from_pretrained(
#    1583         model_name_or_path,
#    1584         torch_dtype=torch_dtype,
#    1585         low_cpu_mem_usage=True,
# ...
