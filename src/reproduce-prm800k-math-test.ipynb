# %%
# import argparse
import gzip
import json
import random
from collections import defaultdict
from typing import Any, Callable, Dict, List, Optional, Tuple

import blobfile as bf
import numpy as np
import orjson

Sample = Dict[str, Any]


def json_loads(s: str) -> Dict:
    try:
        return orjson.loads(s)
    except Exception:
        return json.loads(s)  # fallback


def open_jsonl(file: str):
    if file.endswith(".gz"):
        return gzip.open(bf.BlobFile(file, "rb"))
    return bf.BlobFile(file, "r")


def _read_jsonl(file: str) -> List[Dict]:
    assert bf.exists(file), file
    with open_jsonl(file) as f:
        return [json_loads(l) for l in f.readlines() if l]


def _key_by_problem(samples: List[Dict]):
    grouped_samples = defaultdict(list)
    for sample in samples:
        grouped_samples[sample["problem"]].append(sample)
    return grouped_samples


def _get_answer(sample: Sample) -> Optional[str]:
    return sample.get("answer", sample.get("given_answer", None))


def _choose_sample_by_score(samples: List[Sample], key: str) -> Optional[Sample]:
    if len(samples) == 0:
        return None
    return max(samples, key=lambda x: x[key])

# %%
# __DEBUG__ = True
__DEBUG__ = False
method = "prm"  # one of ['orm', 'prm']


if __DEBUG__:
    n_trials = 1
    ns = [10]
else:
    n_trials = 400
    ns = [10, 25, 50, 75, 100, 200, 300, 400, 500, 750, 1000, 1250, 1500, 1860]

# %%
# samples_path = "az://openaipublic/process-supervision/scored-test-samples.jsonl"
samples_path = "/data/tongyx361/reward-by-prm800k/datasets/scored-test-samples.jsonl"
num_samples_per_problem = 1860


print(f"Reading {samples_path}, this may take a while...")
samples = _read_jsonl(samples_path)
print("Done.")
samples_by_problem = _key_by_problem(samples)  # group samples by problem
num_problems = len(samples_by_problem)  # num of problmes
# Out:
# Reading /data/tongyx361/reward-by-prm800k/datasets/scored-test-samples.jsonl, this may take a while...
# Done.

# %%
def get_n_subsamples(problem_samples, n):
    # # bug?
    if __DEBUG__:
        print("len(problem_samples)", len(problem_samples))
    nones = [None] * (
        num_samples_per_problem - len(problem_samples)
    )  # ::TODO:: 为什么要混入 None？
    problem_samples = problem_samples + nones
    random.shuffle(problem_samples)
    subsamples = list(problem_samples[:n])
    if __DEBUG__:
        print("len(subsamples)", len(subsamples))
    subsamples = [x for x in subsamples if x is not None]
    if __DEBUG__:
        print("len(subsamples_not_none)", len(subsamples))
    subsamples = [x for x in subsamples if _get_answer(x) is not None]
    if __DEBUG__:
        print("len(subsamples_with_answer)", len(subsamples))
    return subsamples

# %%
all_trial_pass_rates = []

for i in range(n_trials):
    pass_rates = []
    for n in ns:
        num_correct = 0
        for problem, problem_samples in samples_by_problem.items():
            subsamples = get_n_subsamples(problem_samples, n)

            if method == "prm":
                choice = _choose_sample_by_score(subsamples, "prm_score")
            elif method == "orm":
                choice = _choose_sample_by_score(subsamples, "orm_score")

            if choice is not None and choice["is_correct"]:
                num_correct += 1
        pass_rates.append(num_correct / num_problems)
    all_trial_pass_rates.append(pass_rates)
    print(f"Trial {i}/{n_trials} {pass_rates}")
# Out:
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1854
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1843
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1852
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1777
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1847
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1162
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1708
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1794
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1641
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1772
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1847
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1852
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1842
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1628
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1845
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1854
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1651
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 911
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1546
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1700
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1852
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1845
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1818
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1276
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 755
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1146
# len(subsamples) 10
# len(subsamples_not_none) 4
# len(subsamples_with_answer) 4
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1522
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1182
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1850
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1768
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 978
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1464
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1402
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1429
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1704
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1830
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1805
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1776
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 985
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1723
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1644
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1841
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1848
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1615
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1823
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 619
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1833
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1798
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 820
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1811
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1835
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1726
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1323
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 570
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 708
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 688
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 670
# len(subsamples) 10
# len(subsamples_not_none) 1
# len(subsamples_with_answer) 1
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 152
# len(subsamples) 10
# len(subsamples_not_none) 1
# len(subsamples_with_answer) 1
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1853
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1617
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1085
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1802
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1795
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 629
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 588
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1850
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1846
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1838
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1810
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1736
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1101
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1809
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1846
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1828
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1771
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1836
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 862
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1508
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1781
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1290
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1793
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1740
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1767
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1836
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1805
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1853
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1136
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1356
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1778
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1173
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 499
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1809
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1639
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1444
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1779
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1797
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1561
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1684
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1627
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1855
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1294
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 764
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1774
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1222
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1401
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1853
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 400
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1422
# len(subsamples) 10
# len(subsamples_not_none) 4
# len(subsamples_with_answer) 4
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1767
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1425
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1802
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1421
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1843
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1631
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1254
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1818
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1385
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1728
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1477
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1825
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1847
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1847
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1852
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1782
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1262
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1763
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1297
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1431
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 775
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1799
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1536
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1524
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 847
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1845
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1850
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 492
# len(subsamples) 10
# len(subsamples_not_none) 0
# len(subsamples_with_answer) 0
# len(problem_samples) 1423
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1515
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1710
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1842
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1667
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1663
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1511
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 762
# len(subsamples) 10
# len(subsamples_not_none) 4
# len(subsamples_with_answer) 4
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1671
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 669
# len(subsamples) 10
# len(subsamples_not_none) 4
# len(subsamples_with_answer) 4
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1835
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 842
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1807
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1489
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1822
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1729
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1854
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1819
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1181
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1572
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1722
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1550
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 187
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1805
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1851
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1602
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1834
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1508
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1769
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1842
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 305
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1816
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1854
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1725
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1787
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1852
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1655
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1740
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 215
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1851
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1818
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1447
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1839
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1743
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 634
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1664
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1757
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 529
# len(subsamples) 10
# len(subsamples_not_none) 4
# len(subsamples_with_answer) 4
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1484
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1605
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1744
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1648
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1835
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1691
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1844
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1781
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1827
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1758
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1772
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1780
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1554
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 863
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1793
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1687
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1837
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 464
# len(subsamples) 10
# len(subsamples_not_none) 1
# len(subsamples_with_answer) 1
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1831
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1730
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1581
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1853
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1825
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1848
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1833
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1782
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1023
# len(subsamples) 10
# len(subsamples_not_none) 1
# len(subsamples_with_answer) 1
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1844
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1834
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1629
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1592
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1471
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1290
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1754
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1818
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1611
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1728
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1852
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1074
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1355
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1322
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 432
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 949
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1746
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 636
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1605
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 989
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1570
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1851
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1683
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1841
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 284
# len(subsamples) 10
# len(subsamples_not_none) 4
# len(subsamples_with_answer) 4
# len(problem_samples) 1799
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1192
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 171
# len(subsamples) 10
# len(subsamples_not_none) 1
# len(subsamples_with_answer) 1
# len(problem_samples) 1442
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1682
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1842
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1771
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 871
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1729
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1822
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1834
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1617
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 835
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1829
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1066
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1846
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1819
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1714
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1849
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1840
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1782
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1225
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1836
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1330
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1652
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1807
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1794
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1812
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1018
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1841
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1254
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1128
# len(subsamples) 10
# len(subsamples_not_none) 2
# len(subsamples_with_answer) 2
# len(problem_samples) 1661
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1165
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1837
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1273
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 600
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 607
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1621
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1815
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1386
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1851
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 460
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1841
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1183
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1850
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 225
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1856
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1784
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1652
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1839
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1778
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1848
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1859
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1664
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1750
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1412
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1857
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1851
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1438
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 828
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1827
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1809
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1765
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 591
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1731
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1858
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1737
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1676
# len(subsamples) 10
# len(subsamples_not_none) 8
# len(subsamples_with_answer) 8
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1838
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1583
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1846
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 944
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 970
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 782
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1583
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1306
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1526
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1778
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1698
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1786
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1223
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1841
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1860
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1849
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 791
# len(subsamples) 10
# len(subsamples_not_none) 6
# len(subsamples_with_answer) 6
# len(problem_samples) 1715
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 1654
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# len(problem_samples) 867
# len(subsamples) 10
# len(subsamples_not_none) 5
# len(subsamples_with_answer) 5
# len(problem_samples) 1498
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 1715
# len(subsamples) 10
# len(subsamples_not_none) 10
# len(subsamples_with_answer) 10
# len(problem_samples) 1107
# len(subsamples) 10
# len(subsamples_not_none) 7
# len(subsamples_with_answer) 7
# len(problem_samples) 378
# len(subsamples) 10
# len(subsamples_not_none) 3
# len(subsamples_with_answer) 3
# len(problem_samples) 1783
# len(subsamples) 10
# len(subsamples_not_none) 9
# len(subsamples_with_answer) 9
# Trial 0/1 [0.682]

# %%
np_all_trial_pass_rates = np.array(all_trial_pass_rates)
print("Mean:", list(np.mean(np_all_trial_pass_rates, axis=0)))
print("Standard deviation:", list(np.std(np_all_trial_pass_rates, axis=0)))
# Out:
# Mean: [0.666]
# Standard deviation: [0.0]
